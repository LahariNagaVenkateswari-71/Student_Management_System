# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('students.csv')

# %%
data.head(1)
# Out:
#    Roll_No    Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 0        1  Lahari     IT     1      F   18            85          40
#
#    Mid2_Marks  Quiz_Marks  Final_Marks
# 0          42          18           80

# %%
data.tail(5)
# Out:
#     Roll_No   Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 15       16  sudha    CSE     4      F   21            87          41
# 16       17  Quinn     IT     1      M   18            69          29
# 17       18   Ravi    CSE     2      M   19            78          34
# 18       19  priya    ECE     3      F   20            92          46
# 19       20    Tom   MECH     4      M   21            76          37
#
#     Mid2_Marks  Quiz_Marks  Final_Marks
# 15          42          18           86
# 16          30          12           64
# 17          33          13           73
# 18          47          19           91
# 19          38          15           78

# %%
data.shape
# Out:
# (20, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Roll_No       20 non-null     int64
#  1   Name          20 non-null     object
#  2   Branch        20 non-null     object
#  3   Year          20 non-null     int64
#  4   Gender        20 non-null     object
#  5   Age           20 non-null     int64
#  6   Attendance_%  20 non-null     int64
#  7   Mid1_Marks    20 non-null     int64
#  8   Mid2_Marks    20 non-null     int64
#  9   Quiz_Marks    20 non-null     int64
#  10  Final_Marks   20 non-null     int64
# dtypes: int64(8), object(3)
# memory usage: 1.8+ KB

# %%
data.describe()
# Out:
#         Roll_No       Year        Age  Attendance_%  Mid1_Marks  Mid2_Marks  \
# count  20.00000  20.000000  20.000000     20.000000   20.000000   20.000000
# mean   10.50000   2.500000  19.500000     78.600000   36.350000   37.200000
# std     5.91608   1.147079   1.147079      9.896304    6.667083    7.045715
# min     1.00000   1.000000  18.000000     60.000000   25.000000   26.000000
# 25%     5.75000   1.750000  18.750000     71.500000   30.750000   31.500000
# 50%    10.50000   2.500000  19.500000     77.500000   36.500000   36.500000
# 75%    15.25000   3.250000  20.250000     87.250000   41.250000   42.250000
# max    20.00000   4.000000  21.000000     95.000000   47.000000   49.000000
#
#        Quiz_Marks  Final_Marks
# count    20.00000    20.000000
# mean     15.00000    75.450000
# std       3.32455    11.468378
# min       9.00000    55.000000
# 25%      12.75000    67.250000
# 50%      15.00000    74.500000
# 75%      18.00000    83.750000
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['Name']
# Out:
# 0      Lahari
# 1       madhu
# 2      prudvi
# 3       David
# 4     Lakshmi
# 5       Frank
# 6      kusuma
# 7        ritu
# 8         Ian
# 9        Jack
# 10      Kiran
# 11      Lasya
# 12       Mike
# 13       Nina
# 14      Oscar
# 15      sudha
# 16      Quinn
# 17       Ravi
# 18      priya
# 19        Tom
# Name: Name, dtype: object

# %%
data.iloc[0]
# Out:
# Roll_No              1
# Name            Lahari
# Branch              IT
# Year                 1
# Gender               F
# Age                 18
# Attendance_%        85
# Mid1_Marks          40
# Mid2_Marks          42
# Quiz_Marks          18
# Final_Marks         80
# Name: 0, dtype: object

# %%
type(data.iloc[0])
# Out:
# pandas.core.series.Series

# %%
mask = (data["Branch"] == "CSE")
data[mask]
# Out:
#     Roll_No   Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 3         4  David    CSE     4      M   21            90          45
# 10       11  Kiran    CSE     3      M   20            77          42
# 15       16  sudha    CSE     4      F   21            87          41
# 17       18   Ravi    CSE     2      M   19            78          34
#
#     Mid2_Marks  Quiz_Marks  Final_Marks
# 3           48          20           90
# 10          43          17           83
# 15          42          18           86
# 17          33          13           73

# %%
mask = data['Branch'] == 'CSE'
mask2 = data['Gender'] == 'F'
data[mask & mask2].shape[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 mask = data['Branch'] == 'CSE'
#       2 mask2 = data['Gender'] == 'F'
#       3 data[mask & mask2].shape[0]
#
# NameError: name 'data' is not defined

# %%
def count_Avg_Attendance(value):
    count = data['Attendance_%']>=value
    return (data[count].shape[0])
count_Avg_Attendance(75)
# Out:
# 12

# %%
import pandas as pd

# %%
data = pd.read_csv('students.csv')

# %%
data['Branch'].value_counts()
#categorical only
# Out:
# Branch
# IT       4
# ECE      4
# CSE      4
# MECH     4
# EEE      2
# CIVIL    2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
#plot liberary

# %%
data['Branch'].value_counts().plot(kind = 'pie')
#graphs for categorical variable
# Out:
# <Axes: ylabel='count'>

# %%
data['Quiz_Marks'].value_counts().head().plot(kind = 'barh')
# Out:
# <Axes: ylabel='Quiz_Marks'>

# %%
data['Quiz_Marks'].value_counts().plot(kind = 'hist')
#histographical graph for integer variables
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.head()
# Out:
#    Roll_No     Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 0        1   Lahari     IT     1      F   18            85          40
# 1        2    madhu    ECE     2      M   19            72          35
# 2        3   prudvi    EEE     3      M   20            68          30
# 3        4    David    CSE     4      M   21            90          45
# 4        5  Lakshmi   MECH     1      F   18            80          38
#
#    Mid2_Marks  Quiz_Marks  Final_Marks
# 0          42          18           80
# 1          34          15           70
# 2          32          12           65
# 3          48          20           90
# 4          36          14           75

# %%
mySeries = data['Branch'].value_counts()

# %%
mySeries
# Out:
# Branch
# IT       4
# ECE      4
# CSE      4
# MECH     4
# EEE      2
# CIVIL    2
# Name: count, dtype: int64

# %%
mySeries.index
# Out:
# Index(['IT', 'ECE', 'CSE', 'MECH', 'EEE', 'CIVIL'], dtype='object', name='Branch')

# %%
mySeries.values
# Out:
# array([4, 4, 4, 4, 2, 2])

# %%
mySeries['CSE']
# Out:
# np.int64(4)

# %%
data['Branch'].value_counts() + data['Branch'].value_counts()
#adding individually by each
# Out:
# Branch
# IT       8
# ECE      8
# CSE      8
# MECH     8
# EEE      4
# CIVIL    4
# Name: count, dtype: int64

# %%
data['Branch'].value_counts().sort_values()
#for sorting values
# Out:
# Branch
# CIVIL    2
# EEE      2
# IT       4
# ECE      4
# MECH     4
# CSE      4
# Name: count, dtype: int64

# %%
data['Branch'].value_counts().sort_values(ascending=False)
# Out:
# Branch
# IT       4
# ECE      4
# CSE      4
# MECH     4
# EEE      2
# CIVIL    2
# Name: count, dtype: int64

# %%
data.sort_values('Final_Marks',ascending=False).head()
# Out:
#     Roll_No   Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 14       15  Oscar   MECH     3      M   20            91          47
# 7         8   ritu    ECE     4      F   21            95          44
# 18       19  priya    ECE     3      F   20            92          46
# 3         4  David    CSE     4      M   21            90          45
# 15       16  sudha    CSE     4      F   21            87          41
#
#     Mid2_Marks  Quiz_Marks  Final_Marks
# 14          49          20           95
# 7           45          19           92
# 18          47          19           91
# 3           48          20           90
# 15          42          18           86

# %%
data.sort_values('Final_Marks',ascending=False,inplace=True)
#perminent changes happened - inplace(default value is false)

# %%
data.head()
# Out:
#     Roll_No   Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 14       15  Oscar   MECH     3      M   20            91          47
# 7         8   ritu    ECE     4      F   21            95          44
# 18       19  priya    ECE     3      F   20            92          46
# 3         4  David    CSE     4      M   21            90          45
# 15       16  sudha    CSE     4      F   21            87          41
#
#     Mid2_Marks  Quiz_Marks  Final_Marks
# 14          49          20           95
# 7           45          19           92
# 18          47          19           91
# 3           48          20           90
# 15          42          18           86

# %%
data.sort_values(['Branch','Final_Marks'])
# Out:
#     Roll_No     Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 5         6    Frank  CIVIL     2      M   19            74          28
# 11       12    Lasya  CIVIL     4      F   21            65          27
# 17       18     Ravi    CSE     2      M   19            78          34
# 10       11    Kiran    CSE     3      M   20            77          42
# 15       16    sudha    CSE     4      F   21            87          41
# 3         4    David    CSE     4      M   21            90          45
# 1         2    madhu    ECE     2      M   19            72          35
# 13       14     Nina    ECE     2      F   19            73          36
# 18       19    priya    ECE     3      F   20            92          46
# 7         8     ritu    ECE     4      F   21            95          44
# 2         3   prudvi    EEE     3      M   20            68          30
# 8         9      Ian    EEE     1      M   18            70          31
# ...

# %%
#if Branch is Ascending order and marks id descending order
data.sort_values(['Branch','Final_Marks'],ascending = [True,False]).head()
# Out:
#     Roll_No   Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 11       12  Lasya  CIVIL     4      F   21            65          27
# 5         6  Frank  CIVIL     2      M   19            74          28
# 3         4  David    CSE     4      M   21            90          45
# 15       16  sudha    CSE     4      F   21            87          41
# 10       11  Kiran    CSE     3      M   20            77          42
#
#     Mid2_Marks  Quiz_Marks  Final_Marks
# 11          28          11           62
# 5           29          10           60
# 3           48          20           90
# 15          42          18           86
# 10          43          17           83

# %%
data.drop_duplicates(subset = ['Branch'])
#change still there because in aove code we put inplace
#it is a temperarory operation not like inplace
# Out:
#     Roll_No    Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 14       15   Oscar   MECH     3      M   20            91          47
# 7         8    ritu    ECE     4      F   21            95          44
# 3         4   David    CSE     4      M   21            90          45
# 0         1  Lahari     IT     1      F   18            85          40
# 8         9     Ian    EEE     1      M   18            70          31
# 11       12   Lasya  CIVIL     4      F   21            65          27
#
#     Mid2_Marks  Quiz_Marks  Final_Marks
# 14          49          20           95
# 7           45          19           92
# 3           48          20           90
# 0           42          18           80
# 8           30          13           68
# 11          28          11           62

# %%
data.drop_duplicates(subset=['Branch','Gender'])
# Out:
#     Roll_No     Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 14       15    Oscar   MECH     3      M   20            91          47
# 7         8     ritu    ECE     4      F   21            95          44
# 3         4    David    CSE     4      M   21            90          45
# 15       16    sudha    CSE     4      F   21            87          41
# 0         1   Lahari     IT     1      F   18            85          40
# 4         5  Lakshmi   MECH     1      F   18            80          38
# 12       13     Mike     IT     1      M   18            82          33
# 1         2    madhu    ECE     2      M   19            72          35
# 8         9      Ian    EEE     1      M   18            70          31
# 11       12    Lasya  CIVIL     4      F   21            65          27
# 5         6    Frank  CIVIL     2      M   19            74          28
#
#     Mid2_Marks  Quiz_Marks  Final_Marks
# 14          49          20           95
# ...

# %%
data.drop_duplicates('Branch',keep='last')[['Branch','Final_Marks']].sort_values('Final_Marks')
# Out:
#    Branch  Final_Marks
# 6      IT           55
# 5   CIVIL           60
# 2     EEE           65
# 1     ECE           70
# 17    CSE           73
# 4    MECH           75

# %%
sector = data.groupby('Branch')
#how many diff sectors created in that variable

# %%
sector.size()
# Out:
# Branch
# CIVIL    2
# CSE      4
# ECE      4
# EEE      2
# IT       4
# MECH     4
# dtype: int64

# %%
data['Branch'].value_counts()
# Out:
# Branch
# MECH     4
# ECE      4
# CSE      4
# IT       4
# EEE      2
# CIVIL    2
# Name: count, dtype: int64

# %%
sector.first()
# Out:
#         Roll_No    Name  Year Gender  Age  Attendance_%  Mid1_Marks  \
# Branch
# CIVIL        12   Lasya     4      F   21            65          27
# CSE           4   David     4      M   21            90          45
# ECE           8    ritu     4      F   21            95          44
# EEE           9     Ian     1      M   18            70          31
# IT            1  Lahari     1      F   18            85          40
# MECH         15   Oscar     3      M   20            91          47
#
#         Mid2_Marks  Quiz_Marks  Final_Marks
# Branch
# CIVIL           28          11           62
# CSE             48          20           90
# ECE             45          19           92
# EEE             30          13           68
# IT              42          18           80
# MECH            49          20           95

# %%
sector.last()
# Out:
#         Roll_No     Name  Year Gender  Age  Attendance_%  Mid1_Marks  \
# Branch
# CIVIL         6    Frank     2      M   19            74          28
# CSE          18     Ravi     2      M   19            78          34
# ECE           2    madhu     2      M   19            72          35
# EEE           3   prudvi     3      M   20            68          30
# IT            7   kusuma     3      F   20            60          25
# MECH          5  Lakshmi     1      F   18            80          38
#
#         Mid2_Marks  Quiz_Marks  Final_Marks
# Branch
# CIVIL           29          10           60
# CSE             33          13           73
# ECE             34          15           70
# EEE             32          12           65
# IT              26           9           55
# MECH            36          14           75

# %%
import pandas as pd

# %%
data = pd.read_csv('students.csv')

# %%
data.iloc[0]
# Out:
# Roll_No              1
# Name            Lahari
# Branch              IT
# Year                 1
# Gender               F
# Age                 18
# Attendance_%        85
# Mid1_Marks          40
# Mid2_Marks          42
# Quiz_Marks          18
# Final_Marks         80
# Name: 0, dtype: object

# %%
groups = data.groupby('Branch')['Final_Marks']
groups.size().sort_values(ascending=True)
# Out:
# Branch
# CIVIL    2
# EEE      2
# CSE      4
# ECE      4
# IT       4
# MECH     4
# Name: Final_Marks, dtype: int64

# %%
groups.first() #group.last()
# Out:
# Branch
# CIVIL    60
# CSE      90
# ECE      70
# EEE      65
# IT       80
# MECH     75
# Name: Final_Marks, dtype: int64

# %%
groups.groups
# Out:
# {'CIVIL': [5, 11], 'CSE': [3, 10, 15, 17], 'ECE': [1, 7, 13, 18], 'EEE': [2, 8], 'IT': [0, 6, 12, 16], 'MECH': [4, 9, 14, 19]}

# %%
data.iloc[18, :] #print exact row (starts with 0) .iloc[18,coloumns]
# Out:
# Roll_No            19
# Name            priya
# Branch            ECE
# Year                3
# Gender              F
# Age                20
# Attendance_%       92
# Mid1_Marks         46
# Mid2_Marks         47
# Quiz_Marks         19
# Final_Marks        91
# Name: 18, dtype: object

# %%
groupss = data.groupby('Gender')
groupss.get_group('M')
#groupss.get_group('F') we can use for manything acessing
# Out:
#     Roll_No    Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 1         2   madhu    ECE     2      M   19            72          35
# 2         3  prudvi    EEE     3      M   20            68          30
# 3         4   David    CSE     4      M   21            90          45
# 5         6   Frank  CIVIL     2      M   19            74          28
# 8         9     Ian    EEE     1      M   18            70          31
# 9        10    Jack   MECH     2      M   19            88          39
# 10       11   Kiran    CSE     3      M   20            77          42
# 12       13    Mike     IT     1      M   18            82          33
# 14       15   Oscar   MECH     3      M   20            91          47
# 16       17   Quinn     IT     1      M   18            69          29
# 17       18    Ravi    CSE     2      M   19            78          34
# 19       20     Tom   MECH     4      M   21            76          37
#
#     Mid2_Marks  Quiz_Marks  Final_Marks
# ...

# %%
mask = data['Gender']=='M'
print(data[mask]) 
#only to print like filtering
# Out:
#     Roll_No    Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 1         2   madhu    ECE     2      M   19            72          35
# 2         3  prudvi    EEE     3      M   20            68          30
# 3         4   David    CSE     4      M   21            90          45
# 5         6   Frank  CIVIL     2      M   19            74          28
# 8         9     Ian    EEE     1      M   18            70          31
# 9        10    Jack   MECH     2      M   19            88          39
# 10       11   Kiran    CSE     3      M   20            77          42
# 12       13    Mike     IT     1      M   18            82          33
# 14       15   Oscar   MECH     3      M   20            91          47
# 16       17   Quinn     IT     1      M   18            69          29
# 17       18    Ravi    CSE     2      M   19            78          34
# 19       20     Tom   MECH     4      M   21            76          37
#
#     Mid2_Marks  Quiz_Marks  Final_Marks
# ...

# %%
Marks = data.groupby('Name')

# %%
Marks['Final_Marks'].mean().sort_values(ascending=True)
# Out:
# Name
# kusuma     55.0
# Frank      60.0
# Lasya      62.0
# Quinn      64.0
# prudvi     65.0
# Ian        68.0
# madhu      70.0
# Mike       71.0
# Ravi       73.0
# Nina       74.0
# Lakshmi    75.0
# Jack       77.0
# Tom        78.0
# Lahari     80.0
# Kiran      83.0
# sudha      86.0
# David      90.0
# priya      91.0
# ritu       92.0
# Oscar      95.0
# Name: Final_Marks, dtype: float64

# %%
import pandas as pd

# %%
data = pd.read_csv("students.csv")

# %%
data
# Out:
#     Roll_No     Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 0         1   Lahari     IT     1      F   18            85          40
# 1         2    madhu    ECE     2      M   19            72          35
# 2         3   prudvi    EEE     3      M   20            68          30
# 3         4    David    CSE     4      M   21            90          45
# 4         5  Lakshmi   MECH     1      F   18            80          38
# 5         6    Frank  CIVIL     2      M   19            74          28
# 6         7   kusuma     IT     3      F   20            60          25
# 7         8     ritu    ECE     4      F   21            95          44
# 8         9      Ian    EEE     1      M   18            70          31
# 9        10     Jack   MECH     2      M   19            88          39
# 10       11    Kiran    CSE     3      M   20            77          42
# 11       12    Lasya  CIVIL     4      F   21            65          27
# ...

# %%
mask = data['Attendance_%'] >= 75
new_mask = data[mask]
new_mask
# Out:
#     Roll_No     Name Branch  Year Gender  Age  Attendance_%  Mid1_Marks  \
# 0         1   Lahari     IT     1      F   18            85          40
# 3         4    David    CSE     4      M   21            90          45
# 4         5  Lakshmi   MECH     1      F   18            80          38
# 7         8     ritu    ECE     4      F   21            95          44
# 9        10     Jack   MECH     2      M   19            88          39
# 10       11    Kiran    CSE     3      M   20            77          42
# 12       13     Mike     IT     1      M   18            82          33
# 14       15    Oscar   MECH     3      M   20            91          47
# 15       16    sudha    CSE     4      F   21            87          41
# 17       18     Ravi    CSE     2      M   19            78          34
# 18       19    priya    ECE     3      F   20            92          46
# 19       20      Tom   MECH     4      M   21            76          37
#
# ...

# %%
new_mask.groupby('Branch')['Final_Marks'].count().sort_values(ascending=True)
#[final_marks] colums here count() counts non null values of the fianl_marks
# Out:
# Branch
# ECE     2
# IT      2
# CSE     4
# MECH    4
# Name: Final_Marks, dtype: int64
